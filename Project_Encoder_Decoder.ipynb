# %% [markdown]
# **Analisis Implementasi Encoder-Decoder**
#
# ## 1. Aplikasi atau Kasus Penggunaan
# - Menggunakan model Encoder-Decoder berbasis LSTM untuk menerjemahkan teks.
# - Diterapkan untuk penerjemahan dari bahasa Toraja ke Bahasa Indonesia.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, Dropout
from tensorflow.keras.models import Model
import numpy as np
import pandas as pd

# Dataset
dataset = [
    ("<start> Kombai <end>", "<start> Apa kabar? <end>"),
    ("<start> Manta'de <end>", "<start> Baik-baik saja <end>"),
    ("<start> Pa'tabe' <end>", "<start> Permisi <end>"),
    ("<start> Tammu' langi' <end>", "<start> Selamat pagi <end>"),
    ("<start> Kumande'ko? <end>", "<start> Apakah kamu sudah makan? <end>"),
    ("<start> Umbain? <end>", "<start> Apa itu? <end>"),
    ("<start> Sule? <end>", "<start> Di mana? <end>"),
    ("<start> Narombo? <end>", "<start> Kenapa? <end>"),
    ("<start> Indan muane? <end>", "<start> Siapa laki-laki itu? <end>"),
    ("<start> Indan baine? <end>", "<start> Siapa perempuan itu? <end>"),
    ("<start> Umba' ko? <end>", "<start> Kamu dari mana? <end>"),
    ("<start> Tammu' ko? <end>", "<start> Apakah kamu baik-baik saja? <end>"),
    ("<start> Sikamali' <end>", "<start> Terima kasih <end>"),
    ("<start> Mangrara banua <end>", "<start> Membangun rumah <end>"),
    ("<start> Pumate' <end>", "<start> Meninggal <end>"),
    ("<start> Malleke' <end>", "<start> Pergi <end>"),
    ("<start> Manapa'ko? <end>", "<start> Apa yang kamu lakukan? <end>"),
    ("<start> Bassi'ka <end>", "<start> Hujan <end>"),
    ("<start> Tallangko' <end>", "<start> Jatuh <end>"),
    ("<start> Allo tau? <end>", "<start> Hari ini apa? <end>"),
    ("<start> Kema'na ko? <end>", "<start> Kamu mau ke mana? <end>"),
    ("<start> Tabe' <end>", "<start> Maaf <end>"),
    ("<start> Tammu' to dolo' <end>", "<start> Orang dulu bilang <end>"),
    ("<start> Kema'na inai? <end>", "<start> Ibunya ke mana? <end>"),
    ("<start> Nasang tani' <end>", "<start> Tidak tahu <end>"),
    ("<start> Umbai'na mako? <end>", "<start> Apa yang dia katakan? <end>"),
    ("<start> Na'ala tu? <end>", "<start> Sudah diambil? <end>"),
    ("<start> Tammu' rara <end>", "<start> Selamat sore <end>"),
    ("<start> Nai' to dolota' <end>", "<start> Ini cerita orang tua <end>"),
    ("<start> Kema'na sangngambu? <end>", "<start> Ke mana anak kecil itu? <end>"),
    ("<start> Pa'rapo <end>", "<start> Menunggu <end>"),
    ("<start> Na'bangka <end>", "<start> Meninggalkan sesuatu <end>"),
    ("<start> Umbai' sangpuru' <end>", "<start> Di mana tempat sembahyang? <end>"),
    ("<start> Tamali'ko? <end>", "<start> Bagaimana kabarmu? <end>"),
    ("<start> Umbai' untu' mu? <end>", "<start> Di mana gigimu? <end>"),
    ("<start> Unni' tau untu' <end>", "<start> Anak yang kehilangan gigi <end>"),
    ("<start> Bangko' duka'na? <end>", "<start> Kenapa kamu sedih? <end>"),
    ("<start> Ledo'? <end>", "<start> Lapar? <end>"),
    ("<start> Uru'na sala <end>", "<start> Kesalahan pertama <end>"),
    ("<start> Nasang tau <end>", "<start> Tidak ada orang <end>"),
    ("<start> Tallangko' sangka' <end>", "<start> Jatuh ke bawah <end>"),
    ("<start> Masambo <end>", "<start> Beristirahat <end>"),
    ("<start> Ira' lisu'? <end>", "<start> Kapan kamu pulang? <end>"),
    ("<start> Pa'pada <end>", "<start> Sama-sama <end>"),
    ("<start> Makka' biang <end>", "<start> Menyapu halaman <end>"),
    ("<start> Tamali' allo <end>", "<start> Hari ini cerah <end>"),
    ("<start> Na'mu kalua? <end>", "<start> Sudah selesai? <end>"),
    ("<start> Tallang sang rampa' <end>", "<start> Jatuh di depan <end>"),
    ("<start> Bangko' lako' <end>", "<start> Mau pergi ke mana? <end>"),
    ("<start> Tammu' tallu <end>", "<start> Tiga orang berkumpul <end>")
]

# %% [markdown]
# ## 2. Arsitektur Encoder-Decoder yang Diimplementasikan
#
# - Model Terdiri dari **Encoder dan Decoder berbasis LSTM**
# - Encoder digunakan untuk mengubah input menjadi vektor konteks
# - Decoder digunakan untuk menerjemahkan vektor konteks menjadi output target.
# - Menggunakan **word Embeddings** untuk representasi kata.

# %%
# Preprocessing Data
input_texts, target_texts = zip(*dataset)

input_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
target_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')

input_tokenizer.fit_on_texts(input_texts)
target_tokenizer.fit_on_texts(target_texts)

input_sequences = input_tokenizer.texts_to_sequences(input_texts)
target_sequences = target_tokenizer.texts_to_sequences(target_texts)

max_encoder_seq_length = max(len(seq) for seq in input_sequences)
max_decoder_seq_length = max(len(seq) for seq in target_sequences)

encoder_input_data = tf.keras.preprocessing.sequence.pad_sequences(input_sequences, maxlen=max_encoder_seq_length, padding='post')
decoder_input_data = tf.keras.preprocessing.sequence.pad_sequences(target_sequences, maxlen=max_decoder_seq_length, padding='post')
decoder_target_data = np.zeros_like(decoder_input_data)
decoder_target_data[:, :-1] = decoder_input_data[:, 1:]

decoder_target_data = np.expand_dims(decoder_target_data, -1)

# %%
# Model Encoder-Decoder
latent_dim = 256

encoder_inputs = Input(shape=(None,))
enc_emb = Embedding(len(input_tokenizer.word_index) + 1, latent_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True, dropout=0.2, recurrent_dropout=0.2)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None,))
dec_emb = Embedding(len(target_tokenizer.word_index) + 1, latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True, dropout=0.2, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)
decoder_dense = Dense(len(target_tokenizer.word_index) + 1, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_13            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_9 (Embedding)   │ (None, None, 256)      │         18,176 │ input_layer_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_10 (Embedding)  │ (None, None, 256)      │         20,992 │ input_layer_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_6 (LSTM)             │ [(None, 256), (None,   │        525,312 │ embedding_9[0][0]      │
# │                           │ 256), (None, 256)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_7 (LSTM)             │ [(None, None, 256),    │        525,312 │ embedding_10[0][0],    │
# │                           │ (None, 256), (None,    │                │ lstm_6[0][1],          │
# │                           │ 256)]                  │                │ lstm_6[0][2]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, None, 82)       │         21,074 │ lstm_7[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,110,866 (4.24 MB)
#  Trainable params: 1,110,866 (4.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Model
history = model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size=32, epochs=300, validation_split=0.2)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.0667 - loss: 4.3948 - val_accuracy: 0.5000 - val_loss: 4.2814
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5024 - loss: 4.2599 - val_accuracy: 0.5000 - val_loss: 4.0779
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5083 - loss: 4.0253 - val_accuracy: 0.5000 - val_loss: 3.6325
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5009 - loss: 3.5057 - val_accuracy: 0.5000 - val_loss: 2.7257
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4994 - loss: 2.5857 - val_accuracy: 0.5000 - val_loss: 2.1917
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4979 - loss: 2.2482 - val_accuracy: 0.5000 - val_loss: 2.3658
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.4964 - loss: 2.5093 - val_accuracy: 0.5000 - val_loss: 2.1851
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5113 - loss: 2.1359 - val_accuracy: 0.5000 - val_loss: 2.0036
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5054 - loss: 1.9519 - val_accuracy: 0.6143 - val_loss: 2.0422
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6330 - loss: 1.9924 - val_accuracy: 0.6429 - val_loss: 2.0973
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6128 - loss: 2.0211 - val_accuracy: 0.6429 - val_loss: 2.0448
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6438 - loss: 1.9451 - val_accuracy: 0.6286 - val_loss: 1.9760
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6268 - loss: 1.8797 - val_accuracy: 0.5714 - val_loss: 1.9406
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5777 - loss: 1.8121 - val_accuracy: 0.5429 - val_loss: 1.9427
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5384 - loss: 1.8246 - val_accuracy: 0.5429 - val_loss: 1.9637
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5435 - loss: 1.8019 - val_accuracy: 0.5571 - val_loss: 1.9741
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5390 - loss: 1.8039 - val_accuracy: 0.5571 - val_loss: 1.9588
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5985 - loss: 1.7294 - val_accuracy: 0.6286 - val_loss: 1.9334
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6366 - loss: 1.7051 - val_accuracy: 0.6286 - val_loss: 1.9138
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6497 - loss: 1.6809 - val_accuracy: 0.6429 - val_loss: 1.9072
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6438 - loss: 1.6954 - val_accuracy: 0.6429 - val_loss: 1.9076
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6542 - loss: 1.6470 - val_accuracy: 0.6429 - val_loss: 1.9087
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6393 - loss: 1.6900 - val_accuracy: 0.6429 - val_loss: 1.9107
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6393 - loss: 1.6812 - val_accuracy: 0.6429 - val_loss: 1.9180
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6482 - loss: 1.6244 - val_accuracy: 0.6429 - val_loss: 1.9327
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0
300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.6801 - loss: 1.2493 - val_accuracy: 0.6571 - val_loss: 2.4039
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6649 - loss: 1.2455 - val_accuracy: 0.6571 - val_loss: 2.4609
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.6863 - loss: 1.2004 - val_accuracy: 0.6429 - val_loss: 2.5737
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6777 - loss: 1.1712 - val_accuracy: 0.6571 - val_loss: 2.5481
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.6824 - loss: 1.1593 - val_accuracy: 0.6571 - val_loss: 2.5022
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7057 - loss: 1.1424 - val_accuracy: 0.6429 - val_loss: 2.6872
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6970 - loss: 1.1185 - val_accuracy: 0.6429 - val_loss: 2.6674
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7036 - loss: 1.1185 - val_accuracy: 0.6571 - val_loss: 2.5724
# Epoch 65/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7476 - loss: 1.0826 - val_accuracy: 0.6571 - val_loss: 2.6813
# Epoch 66/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7170 - loss: 1.0823 - val_accuracy: 0.6571 - val_loss: 2.8236
# Epoch 67/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7065 - loss: 1.0481 - val_accuracy: 0.6571 - val_loss: 2.7640
# Epoch 68/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7238 - loss: 1.0220 - val_accuracy: 0.6571 - val_loss: 2.7438
# Epoch 69/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7268 - loss: 0.9918 - val_accuracy: 0.6571 - val_loss: 2.8051
# Epoch 70/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7339 - loss: 0.9820 - val_accuracy: 0.6571 - val_loss: 2.8704
# Epoch 71/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7274 - loss: 0.9306 - val_accuracy: 0.6571 - val_loss: 2.8015
# Epoch 72/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7568 - loss: 0.9147 - val_accuracy: 0.6571 - val_loss: 2.8086
# Epoch 73/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7485 - loss: 0.8982 - val_accuracy: 0.6571 - val_loss: 2.9109
# Epoch 74/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step - accuracy: 0.7417 - loss: 0.8882 - val_accuracy: 0.6571 - val_loss: 2.9420
# Epoch 75/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.7747 - loss: 0.8494 - val_accuracy: 0.6429 - val_loss: 2.8837
# Epoch 76/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7726 - loss: 0.8281 - val_accuracy: 0.6571 - val_loss: 2.8954
# Epoch 77/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7833 - loss: 0.8266 - val_accuracy: 0.6571 - val_loss: 3.0324
# Epoch 78/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7827 - loss: 0.7714 - val_accuracy: 0.6571 - val_loss: 3.0365
# Epoch 79/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.8021 - loss: 0.7606 - val_accuracy: 0.6286 - val_loss: 2.9751
# Epoch 80/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8354 - loss: 0.7495 - val_accuracy: 0.6571 - val_loss: 3.0878
# Epoch 81/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8321 - loss: 0.7114 - val_accuracy: 0.6571 - val_loss: 3.2674
# Epoch 82/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7679 - loss: 0.7620 - val_accuracy: 0.6429 - val_loss: 3.0699
# Epoch 83/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8324 - loss: 0.6777 - val_accuracy: 0.6429 - val_loss: 2.9974
# Epoch 84/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8399 - loss: 0.6602 - val_accuracy: 0.6286 - val_loss: 3.0757
# Epoch 85/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8548 - loss: 0.6100 - val_accuracy: 0.6571 - val_loss: 3.2314
# Epoch 86/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8122 - loss: 0.6368 - val_accuracy: 0.6143 - val_loss: 3.1525
# Epoch 87/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0
300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.6714 - val_loss: 3.7801
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.6714 - val_loss: 3.7576
# Epoch 186/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.6714 - val_loss: 3.7099
# Epoch 187/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9961 - loss: 0.0204 - val_accuracy: 0.6857 - val_loss: 3.6771
# Epoch 188/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.6571 - val_loss: 3.6585
# Epoch 189/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 0.6571 - val_loss: 3.6501
# Epoch 190/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.6571 - val_loss: 3.6427
# Epoch 191/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.6857 - val_loss: 3.6402
# Epoch 192/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.6857 - val_loss: 3.6501
# Epoch 193/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.6857 - val_loss: 3.6699
# Epoch 194/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.6857 - val_loss: 3.6898
# Epoch 195/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.6857 - val_loss: 3.6994
# Epoch 196/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.6857 - val_loss: 3.7071
# Epoch 197/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.6857 - val_loss: 3.7135
# Epoch 198/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.6857 - val_loss: 3.7160
# Epoch 199/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.6857 - val_loss: 3.7204
# Epoch 200/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.6857 - val_loss: 3.7186
# Epoch 201/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.6857 - val_loss: 3.7180
# Epoch 202/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.6857 - val_loss: 3.7176
# Epoch 203/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.6857 - val_loss: 3.7127
# Epoch 204/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.6857 - val_loss: 3.7102
# Epoch 205/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.6857 - val_loss: 3.7125
# Epoch 206/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.6857 - val_loss: 3.7142
# Epoch 207/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.6857 - val_loss: 3.7123
# Epoch 208/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.6857 - val_loss: 3.7075
# Epoch 209/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.6857 - val_loss: 3.7067
# Epoch 210/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.6857 - val_loss: 3.7113
# Epoch 211/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.6857 - val_loss: 3.7184
# Epoch 212/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.6857 - val_loss: 3.7303
# Epoch 213/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.6857 - val_loss: 3.7461
# Epoch 214/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.6857 - val_loss: 3.7565
# Epoch 215/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.6857 - val_loss: 3.7601
# Epoch 216/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy:
300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.6857 - val_loss: 3.9305
# Epoch 273/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.6857 - val_loss: 3.9094
# Epoch 274/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9961 - loss: 0.0159 - val_accuracy: 0.6857 - val_loss: 3.8381
# Epoch 275/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.6857 - val_loss: 3.8094
# Epoch 276/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.6571 - val_loss: 3.8357
# Epoch 277/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.6571 - val_loss: 3.8590
# Epoch 278/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.6571 - val_loss: 3.8702
# Epoch 279/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.6571 - val_loss: 3.8791
# Epoch 280/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.6714 - val_loss: 3.8899
# Epoch 281/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.6857 - val_loss: 3.9021
# Epoch 282/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.6857 - val_loss: 3.9089
# Epoch 283/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.6857 - val_loss: 3.9126
# Epoch 284/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.6857 - val_loss: 3.9030
# Epoch 285/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.6857 - val_loss: 3.8945
# Epoch 286/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.6857 - val_loss: 3.8851
# Epoch 287/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.6857 - val_loss: 3.8771
# Epoch 288/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.6857 - val_loss: 3.8695
# Epoch 289/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.6857 - val_loss: 3.8623
# Epoch 290/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.6857 - val_loss: 3.8575
# Epoch 291/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.6857 - val_loss: 3.8566
# Epoch 292/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.6857 - val_loss: 3.8576
# Epoch 293/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6857 - val_loss: 3.8594
# Epoch 294/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.6857 - val_loss: 3.8631
# Epoch 295/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6857 - val_loss: 3.8658
# Epoch 296/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6857 - val_loss: 3.8679
# Epoch 297/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.6857 - val_loss: 3.8728
# Epoch 298/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.6857 - val_loss: 3.8748
# Epoch 299/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6857 - val_loss: 3.8773
# Epoch 300/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.6857 - val_loss: 3.8818

# %%
# Inference Model
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
dec_emb2 = Embedding(len(target_tokenizer.word_index) + 1, latent_dim)(decoder_inputs)
decoder_outputs, state_h, state_c = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %%
encoder_model.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)          │ (None, None)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_9 (Embedding)              │ (None, None, 256)           │          18,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_6 (LSTM)                        │ [(None, 256), (None, 256),  │         525,312 │
# │                                      │ (None, 256)]                │                 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 543,488 (2.07 MB)
#  Trainable params: 543,488 (2.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
decoder_model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_11 (Embedding)  │ (None, None, 256)      │         20,992 │ input_layer_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_14            │ (None, 256)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_15            │ (None, 256)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_7 (LSTM)             │ [(None, None, 256),    │        525,312 │ embedding_11[0][0],    │
# │                           │ (None, 256), (None,    │                │ input_layer_14[0][0],  │
# │                           │ 256)]                  │                │ input_layer_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, None, 82)       │         21,074 │ lstm_7[1][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 567,378 (2.16 MB)
#  Trainable params: 567,378 (2.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3. Proses Training dan Dataset yang Digunakan
# - Dataset terdiri dari pasangan teks "<start> Input <end>" dan "<start> Output <end>"
# - Data diproses dengan tokenisasi, padding, dan embedding.
# - Padding digunakan untuk menyamakan panjang sekuens.
# - Model dilatih dengan **categorical cross-entropy loss** dan **Adam optimizer**

# %%
# Beam Search Decoder
def beam_search_decoder(predictions, beam_width=3):
    top_k_indices = np.argsort(predictions[0, -1, :])[-beam_width:]
    sampled_token_index = np.random.choice(top_k_indices)
    return sampled_token_index

# %%
# Function for Translation
def translate(input_text):
    input_seq = tf.keras.preprocessing.sequence.pad_sequences(
        input_tokenizer.texts_to_sequences([input_text]), maxlen=max_encoder_seq_length, padding='post')
    states_value = encoder_model.predict(input_seq)
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = target_tokenizer.word_index['<start>']
    decoded_sentence = []
    stop_condition = False
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        sampled_token_index = beam_search_decoder(output_tokens, beam_width=3)
        sampled_word = target_tokenizer.index_word.get(sampled_token_index, '?')
        if sampled_word == '<end>' or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True
        else:
            decoded_sentence.append(sampled_word)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        states_value = [h, c]
    return ' '.join(decoded_sentence)

# %% [markdown]
# ## 4. Hasil dan Evaluasi Model
# - **Akurasi Training**: **1.0000**
# - **Akurasi Validasi**: **0.6857**
# - **Contoh Hasil Prediksi Model**:
#   - **Input**: "<start> Kombai <end>" → **Output**: "pergi kabar? ?"
#   - **Input**: "<start> Manta'de <end>" → **Output**: "baik-baik"
#   - **Input**: "<start> Pa'tabe' <end>" → **Output**: "permisi permisi ?"
#   - **Input**: "<start> Tammu' langi' <end>" → **Output**: "pagi pagi pagi"
#   - **Input**: "<start> Kumande'ko? <end>" → **Output**: "bagaimana kamu sudah ?"
# - **Analisis Hasil**:
#   - Model menunjukkan **beberapa kesalahan pengulangan kata** dalam hasil terjemahan.
#   - Beberapa output tidak sempurna, tetapi masih memiliki makna yang mendekati target.
#   - Model memiliki **akurasi validasi 68.57%**, menunjukkan ada ruang untuk perbaikan dengan lebih banyak data atau teknik seperti attention mechanism.

# %%
# Test Translation
sample_sentences = [
    "<start> Kombai <end>",
    "<start> Manta'de <end>",
    "<start> Pa'tabe' <end>",
    "<start> Tammu' langi' <end>",
    "<start> Kumande'ko? <end>"
]

for sentence in sample_sentences:
    print(f"Input: {sentence}")
    print(f"Output: {translate(sentence)}")
    print("-")
# Out:
# Input: <start> Kombai <end>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Output: pergi kabar? ?
# -
# Input: <start> Manta'de <end>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Output: baik-baik
# -
# Input: <start> Pa'tabe' <end>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Output: permisi permisi ?
# -
# Input: <start> Tammu' langi' <end>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Output: pagi pagi pagi
# -
# Input: <start> Kumande'ko? <end>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Output: bagaimana kamu sudah ?
# -

# %%
# Display Model Accuracy
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]
print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")
# Out:
# Final Training Accuracy: 1.0000
# Final Validation Accuracy: 0.6857

# %% [markdown]
# # Kesimpulan:
# # Implementasi encoder-decoder berbasis LSTM dalam proyek ini berhasil diterapkan untuk tugas penerjemahan bahasa daerah Toraja ke bahasa Indonesia. Model ini dapat dikembangkan lebih lanjut dengan dataset yang lebih besar dan penggunaan mekanisme **attention** untuk meningkatkan performa.
